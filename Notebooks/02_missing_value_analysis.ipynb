# %% [markdown]
#                                                          OBJECTIVE:-
#                                                    MISSING VALUE ANALYSIS
#
#                         This notebook analyzes the presence and patterns of missing values in the raw dataset.
#
#                 The goal is to understand which features contain missing values and their what patterns they show
#
#                             No preprocessing or data modification is performed in this notebook.

# %%
import pandas as pd

columns = [
    "age", "workclass", "fnlwgt", "education", "education_num",
    "marital_status", "occupation", "relationship", "race", "sex",
    "capital_gain", "capital_loss", "hours_per_week", "native_country",
    "income"
]

df = pd.read_csv(
    "adult_income_raw.csv",
    sep=", ",
    engine="python",
    header=None,
    names=columns,
    na_values="?"
)
print("the dataset is loaded successfully ")
# Out:
# the dataset is loaded successfully

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1837
# fnlwgt               1
# education            1
# education_num        1
# marital_status       1
# occupation        1844
# relationship         1
# race                 1
# sex                  1
# capital_gain         1
# capital_loss         1
# hours_per_week       1
# native_country     584
# income               1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32562 entries, 0 to 32561
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32562 non-null  object
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  float64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  float64
#  5   marital_status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  float64
#  11  capital_loss    32561 non-null  float64
#  12  hours_per_week  32561 non-null  float64
#  13  native_country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 3.7+ MB

# %% [markdown]
# These features show high missingness, suggesting either data collection gaps or non-applicability for certain records.
# Blind imputation may introduce bias.

# %%
Heavy_missingness=df[["workclass","occupation","native_country"]]

# %% [markdown]
# These features contain negligible missing values likely due to parsing or entry errors.
# Handling choices here will not materially affect the dataset.

# %%
Trivial_missingness=df.drop(columns=["workclass","occupation","native_country"])

# %% [markdown]
#                                                 The Table For Missing Patterns and Feature dtype

# %% [markdown]
# | Feature Name                     | Feature Type                         | Missing Pattern     |
# |----------------------------------|--------------------------------------|---------------------|
# | age                              | Numerical                            | No missing values   |
# | workclass                        | Categorical                          | Heavy missingness   |
# | fnlwgt                           | Numerical                            | Trivial missingness |
# | education                        | Categorical                          | Trivial missingness |
# | education_num                    | Numerical                            | Trivial missingness |
# | marital_status                   | Categorical                          | Trivial missingness |
# | occupation                       | Categorical                          | Heavy missingness   |
# | relationship                     | Categorical                          | Trivial missingness |
# | race                             | Categorical                          | Trivial missingness |
# | sex                              | Categorical                          | Trivial missingness |
# | capital_gain                     | Numerical                            | Trivial missingness |
# | capital_loss                     | Numerical                            | Trivial missingness |
# | hours_per_week                   | Numerical                            | Trivial missingness |
# | native_country                   | Categorical                          | Heavy missingness   |
# | income                           | Categorical                          | Trivial missingness |

# %%
Heavy_missingness.head(5)
# Out:
#           workclass         occupation native_country
# 0         State-gov       Adm-clerical  United-States
# 1  Self-emp-not-inc    Exec-managerial  United-States
# 2           Private  Handlers-cleaners  United-States
# 3           Private  Handlers-cleaners  United-States
# 4           Private     Prof-specialty           Cuba

# %%
Heavy_missingness[['occupation', 'workclass']].isna().all(axis=1).sum()
# Out:
# np.int64(1837)

# %% [markdown]
# ->By observing the amount of null values from the pair of occupation column and workclass column we can clearly tell that the null is because either unemployed individuals or data limitations

# %% [markdown]
# ->while the values of numerical column seems to be random and sparse
